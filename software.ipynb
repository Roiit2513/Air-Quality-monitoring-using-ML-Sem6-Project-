# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib

# %%
data=pd.read_csv("MQ9n.csv")

# %%
data
# Out:
#       MQ9  value
# 0     696      1
# 1     674      1
# 2     646      1
# 3     590      1
# 4     627      1
# ...   ...    ...
# 1840  826      1
# 1841  821      1
# 1842  832      1
# 1843  840      1
# 1844  840      1
#
# [1845 rows x 2 columns]

# %%
x=np.array(data)[:,:-1]
y=np.array(data)[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
Logistic=LogisticRegression()
Logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
joblib.dump(Logistic, "model/gas_sensor")
# Out:
# ['model/gas_sensor']

# %%
y_pred=Logistic.predict(x_test)

# %%
Logistic.score(x_test,y_test)
# Out:
# 0.9513513513513514

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9513513513513514

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, Logistic.predict(x_train), color='blue')
plt.title('Gas reading vs Air quality')
plt.xlabel('Gas reading')
plt.ylabel('Air quality')
plt.show()

# %%
import os
import sys
import pickle

# %%
projectabspathname = os.path.abspath('model.pickle')
print(projectabspathname)
projectname = 'Untitled.ipynb'
projectpickle = open(str(projectabspathname),'wb')
pickle.dump(projectname, projectpickle)
projectpickle.close()
# Out:
# D:\ML_project\ML_Sem6_Project\model.pickle
